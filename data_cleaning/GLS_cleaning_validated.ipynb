# %%
import pandas as pd

# %%
df = pd.read_excel('UTF-8100024994_HUF_20250328_080048.xlsx')
# Out:
# C:\Users\hifly\AppData\Roaming\Python\Python312\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.head(10)
# Out:
#           GLS General Logistics Systems Hungary Kft.  Unnamed: 1  \
# 0                                                NaN         NaN
# 1                        Ügyfél név: SULLER-TÁP KFT.         NaN
# 2  Email:: info@kutyakajas.hu;konyveles@szamadok....         NaN
# 3         Bankszámlaszám: 10104459-27057500-02005001         NaN
# 4                       Utalás dátuma: 2025. 03. 28.         NaN
# 5                                                NaN         NaN
# 6                                      Jelentés szám  Csomagszám
# 7                                           79337810  3348922086
# 8                                           79338533  3348931485
# 9                                           79338600  3348932417
#
#            Unnamed: 2          Unnamed: 3      Unnamed: 4 Unnamed: 5  \
# 0                 NaN                 NaN             NaN        NaN
# 1                 NaN                 NaN             NaN        NaN
# ...

# %%
df = df.drop(index=range(0, 7))

# %%
# Remove the last row:
df = df.drop(df.index[-1])

# %%
# Reset the row index
df.reset_index(drop=True, inplace=True)

# %%
# If you want to ensure column indexes start from 0 and are sequential,
# you can simply re-assign a range if needed (though typically column names are used)
df.columns = range(df.shape[1])

# %%
df.head()
# Out:
#           0           1             2           3      4    5  \
# 0  79337810  3348922086  SA25/H031391  2025-03-26   8580  HUF
# 1  79338533  3348931485  SA25/H031431  2025-03-26  22525  HUF
# 2  79338600  3348932417  SA25/H031439  2025-03-26  21500  HUF
# 3  79338673  3348933482  SA25/H031445  2025-03-26  14970  HUF
# 4  79339137  3348939429  SA25/H031478  2025-03-26  20085  HUF
#
#                                                    6
# 0  GLS Automata Win Car WASH HU-8900 ZALAEGERSZEG...
# 1          Dr. Nagy Ákos HU-9437 Hegykő Patak u. 37
# 2  GLS Automata Gold-lakk Festék Szaküzlet HU-210...
# 3  GLS Automata Tesco, Mátészalka HU-4700 MÁTÉSZA...
# 4  GLS Automata Coop ABC, Hajdúdorog, Nánási út 2...

# %%
df = df.iloc[:, [2, 4]]

# %%
df.head()
# Out:
#               2      4
# 0  SA25/H031391   8580
# 1  SA25/H031431  22525
# 2  SA25/H031439  21500
# 3  SA25/H031445  14970
# 4  SA25/H031478  20085

# %%
# Converting the grand total to integer
df[4] = df[4].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2       78 non-null     object
#  1   4       78 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.3+ KB
